# %% [markdown]
# # Dependencies

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, balanced_accuracy_score, precision_score, accuracy_score, recall_score

import pickle

# %% [markdown]
# # Import model

# %%
# Importing components for siRNA complexation classification model
# classifier
clf = pickle.load(open('Data_files/siRNA_complexation_classifier.pkl', 'rb'))
# descriptor scaler
scaler = pickle.load(open('Data_files/siRNA_complexation_classifier_scaler.pkl', 'rb'))
# complete set of 5666 descriptors
descriptors = pickle.load(open('Data_files/siRNA_complexation_classifier_descriptors_all.pkl', 'rb'))
# 5 descriptors used in random forest classifier
desc_sel = pickle.load(open('Data_files/siRNA_complexation_classifier_descriptors_model.pkl', 'rb'))

# %% [markdown]
# # Function defining classification

# %%
# Function to perform prediction
def predict_siRNA_complexation(data_input,name):
    #print(data_input)
    data_output = pd.Series(dtype=str)
    data_output['Name'] = name
    if (data_input['ALOGP'] > 8):
        data_output['Prediction'] = True
        data_output['Comment'] =  'ALOGP > 8.0 - Predicted to complex siRNA'
    elif (data_input['nAB'] <= 12):
        data_output['Prediction'] = False
        data_output['Comment'] = 'ALOGP < 8.0 & nAB <= 12 - Predicted NOT to complex siRNA'
    else:
        data_input['NOArRing'] =  (
        (data_input['nArOR']>0)|
        (data_input['nArOH']>0)|
        (data_input['nArOCN']>0)|
        (data_input['nArNCO']>0)|
        (data_input['nArNCS']>0)|
        (data_input['nArOCON']>0)|
        (data_input['nArNHO']>0)|
        (data_input['nArNNOx']>0)|
        (data_input['nArNO']>0)|
        (data_input['nArNO2']>0)|
        (data_input['nArOX']>0)|
        (data_input['nFuranes']>0)|
        (data_input['nOxazoles']>0)|
        (data_input['nIsoxazoles']>0)|
        (data_input['nArNH2']>0) |
        (data_input['nArNHR']>0) |
        (data_input['nArNR2']>0) |
        (data_input['nPyrroles']>0) |
        (data_input['nPyrazoles']>0) |
        (data_input['nImidazoles']>0) |
        (data_input['nThiazoles']>0) |
        (data_input['nIsothiazoles']>0) |
        (data_input['nTriazoles']>0) |
        (data_input['nPyridines']>0) |
        (data_input['nPyridazines']>0) |
        (data_input['nPyrimidines']>0) |
        (data_input['nPyrazines']>0) |
        (data_input['n135-Triazines']>0) |
        (data_input['n124-Triazines']>0)
        )
        if data_input['NOArRing'] == 0:
            data_output['Prediction'] = False
            data_output['Comment'] = 'ALOGP < 8.0 & nAB > 12 but NOArRing = 0 - Predicted NOT to complex siRNA'
        else:
            #if to_scale == True:
            data_input[descriptors] = scaler.transform(data_input[descriptors].to_frame().T).reshape(-1)
            data_output['Prediction'] = clf.predict(data_input[desc_sel].to_frame().T)[0]
            data_output['Comment'] = 'ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classification model prediction of: '+str(data_output['Prediction'])
    
    return data_output

# %% [markdown]
# # Applying model to all screening data

# %%
data_aug = pd.read_csv('Data_files/data_aug.csv')
data_aug_out = data_aug.apply(lambda x: predict_siRNA_complexation(x,x['NAME']),axis=1)
data_aug_out
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/gb/lk5ckc2n4sq0ml1d8wm6k8gm0000gn/T/ipykernel_66910/2446872285.py in <module>
#       1 data_aug = pd.read_csv('Data_files/data_aug.csv')
# ----> 2 data_aug_out = data_aug.apply(lambda x: predict_siRNA_complexation(x,x['NAME']),axis=1)
#       3 data_aug_out
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /var/folders/gb/lk5ckc2n4sq0ml1d8wm6k8gm0000gn/T/ipykernel_66910/2446872285.py in <lambda>(x)
#       1 data_aug = pd.read_csv('Data_files/data_aug.csv')
# ----> 2 data_aug_out = data_aug.apply(lambda x: predict_siRNA_complexation(x,x['NAME']),axis=1)
#       3 data_aug_out
#
# /var/folders/gb/lk5ckc2n4sq0ml1d8wm6k8gm0000gn/T/ipykernel_66910/3771262198.py in predict_siRNA_complexation(data_input, name)
#      47         else:
#      48             #if to_scale == True:
# ---> 49             data_input[descriptors] = scaler.transform(data_input[descriptors].to_frame().T).reshape(-1)
#      50             data_output['Prediction'] = clf.predict(data_input[desc_sel].to_frame().T)[0]
#      51             data_output['Comment'] = 'ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classification model prediction of: '+str(data_output['Prediction'])
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/frame.py in T(self)
#    3359     @property
#    3360     def T(self) -> DataFrame:
# -> 3361         return self.transpose()
#    3362
#    3363     # ----------------------------------------------------------------------
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/frame.py in transpose(self, copy, *args)
#    3334                 new_vals = new_vals.copy()
#    3335
# -> 3336             result = self._constructor(new_vals, index=self.columns, columns=self.index)
#    3337
#    3338         elif (
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     676                     dtype=dtype,
#     677                     copy=copy,
# --> 678                     typ=manager,
#     679                 )
#     680
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     373         block_values = []
#     374
# --> 375     return create_block_manager_from_blocks(block_values, [columns, index])
#     376
#     377
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes, consolidate)
#    1749
#    1750     if consolidate:
# -> 1751         mgr._consolidate_inplace()
#    1752     return mgr
#    1753
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     622     def _consolidate_inplace(self) -> None:
#     623         if not self.is_consolidated():
# --> 624             self.blocks = tuple(_consolidate(self.blocks))
#     625             self._is_consolidated = True
#     626             self._known_consolidated = True
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1968     # sort by _can_consolidate, dtype
#    1969     gkey = lambda x: x._consolidate_key
# -> 1970     grouper = itertools.groupby(sorted(blocks, key=gkey), gkey)
#    1971
#    1972     new_blocks: list[Block] = []
#
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/pandas/core/internals/managers.py in <lambda>(x)
#    1967     """
#    1968     # sort by _can_consolidate, dtype
# -> 1969     gkey = lambda x: x._consolidate_key
#    1970     grouper = itertools.groupby(sorted(blocks, key=gkey), gkey)
#    1971
#
# KeyboardInterrupt:

# %%
data_aug = data_aug.merge(data_aug_out,left_on='NAME',right_on='Name')

# %%
# generate preductions and confusion matrix for train set
cm = confusion_matrix(data_aug['RG_binary'], data_aug['Prediction'], labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)
disp.plot()

# %% [markdown]
# # Applying model to example test drugs

# %%
# Input file with molecular desecriptors
example_drugs = pd.read_csv('Data_files/descriptors_example_cases.csv')

# Applying function defining classification model
example_drugs_out = example_drugs.apply(lambda x: predict_siRNA_complexation(x,x['NAME']),axis=1)
example_drugs_out
# Out:
#                  Name  Prediction  \
# 0      Emetine analog        True
# 1          Netarsudil        True
# 2  Sorafenib analogue        True
#
#                                              Comment
# 0           ALOGP > 8.0 - Predicted to complex siRNA
# 1  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 2  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...

# %%
# Examining additional parameters relevant for encapsulation and size of IDNPs
example_drugs[['NAME','CMC-80','ALOGP','AMR','nAB','ChiralCenter','nHDon','JGI7','J_G']]
# Out:
#                  NAME  CMC-80   ALOGP    AMR  nAB  ChiralCenter  nHDon  \
# 0      Emetine analog       0  13.210  229.0   12             4      0
# 1          Netarsudil       0   3.901  132.4   23             1      3
# 2  Sorafenib analogue       0   3.938  127.9   23             0      4
#
#       JGI7    J_G
# 0  0.01211  2.367
# 1  0.01011  1.835
# 2  0.00803  1.461

# %% [markdown]
# # Applying model to drugs in DrugBank

# %%
db_molecules = pd.read_csv('Data_files/descriptors_db_filt.csv',low_memory=False)

# remove descriptors with NA values or where error occured
db_molecules = db_molecules.dropna()
db_molecules = db_molecules[db_molecules['ERROR']=='-']
db_molecules[descriptors] = db_molecules[descriptors].apply(pd.to_numeric,axis=0)

# %%
db_molecules_out = db_molecules.apply(lambda x: predict_siRNA_complexation(x,x['NAME']),axis=1)
db_molecules_out.to_csv('Data_files/For_plotting/db_molecules_predictions.csv')
db_molecules_out
# Out:
#               Name  Prediction  \
# 0      INDECAINIDE       False
# 1        reserpine       False
# 2     Azithromycin       False
# 3      Ticlopidine       False
# 4       Citalopram       False
# ...            ...         ...
# 1581      BP-14979       False
# 1582    Revaprazan       False
# 1583      Vicagrel       False
# 1584  Volinanserin       False
# 1585  Mobocertinib       False
#
#                                                 Comment
# 0     ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 1     ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 2     ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 3     ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 4     ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# ...                                                 ...
# 1581  ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 1582  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 1583  ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 1584  ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 1585  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
#
# [1570 rows x 3 columns]

# %%
sum(db_molecules_out['Prediction'])
# Out:
# 363

# %% [markdown]
# # Applying model to drugs that were excluded due to anomalous screening results

# %%
set1_all = pd.read_csv('Data_files/all_data_from_screening_set_1.csv')
all_results_1 = set1_all[['name','SMILES']]
all_results_1['RG_binary'] = (set1_all['RG'] < 0.5)

set2_all = pd.read_csv('Data_files/all_data_from_screening_set_2.csv')
all_results_2 = set2_all[['name','SMILES']]
all_results_2['RG_binary'] = (set2_all["('All', 'RG_mean')"] < 0.5)

all_results = pd.concat([all_results_1,all_results_2])
all_results = all_results.append({'name':'Abemaciclib',
                                  'SMILES':'CCN1CCN(CC2=CC=C(NC3=NC=C(F)C(=N3)C4=CC(F)=C5N=C(C)N(C(C)C)C5=C4)N=C2)CC1',
                                  'RG_binary':True}, 
                                 ignore_index=True)
all_results = all_results.append({'name':'AMG-208',
                                  'SMILES':'COC1=CC2=NC=CC(OCC3=NN=C4C=CC(=NN34)C5=CC=CC=C5)=C2C=C1',
                                  'RG_binary':True}, 
                                 ignore_index=True)
db_filt = pd.read_csv('Data_files/db_filt.csv')
db_molecules = db_filt[['name','drugbank_id']].merge(db_molecules,on='drugbank_id')
db_tested = db_molecules.merge(all_results,on='name')
set1_filt = pd.read_csv('Data_files/RG_for_ML.csv')
set2_filt = pd.read_csv('Data_files/RG_for_ML_2.csv')
excluded_drugs = db_tested[(~db_tested['name'].isin(set1_filt['NAME']))&(~db_tested['name'].isin(set2_filt['NAME']))]
excluded_drugs

# 161 drugs in set 1 in group 1 and 5, 122 tested: 161 - 122 = 39 excluded set 1
# 83 drugs in set 2, 64 tested: 83 - 64 = 19 excluded from set 2
# Total excluded = 39 + 19 = 58
# Out:
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/my-rdkit-env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                  name drugbank_id  \
# 4          Eletriptan     DB00216
# 9         Ziprasidone     DB00246
# 11          Amsacrine     DB00276
# 23        Vinorelbine     DB00361
# 26           Loxapine     DB00408
# 36        Vinblastine     DB00570
# 37        Amodiaquine     DB00613
# 38          Rifabutin     DB00615
# 39           Imatinib     DB00619
# 50        Clopidogrel     DB00758
# 55        Clofazimine     DB00845
# 61   Phenoxybenzamine     DB00925
# 65      Desloratadine     DB00967
# 70         Rifampicin     DB01045
# 72         Atazanavir     DB01072
# 74        Deserpidine     DB01089
# 87        Rifapentine     DB01201
# 91       Aripiprazole     DB01238
# 96          Lapatinib     DB01259
# 97          Sunitinib     DB01268
# 98          Josamycin     DB01321
# 100         Almitrine     DB01430
# 102       Thiothixene     DB01623
# 113       Indacaterol     DB05039
# 114        Rilapladib     DB05119
# 117        Tandutinib     DB05465
# 118       Abiraterone     DB05812
# 119           OSI-930     DB05913
# 129       Enzastaurin     DB06486
# 130         Pazopanib     DB06589
# 131      Panobinostat     DB06603
# 136        Vilazodone     DB06684
# 140          CHIR-124     DB06852
# 141           AMG-208     DB08079
# 143             PQ-10     DB08391
# 148       Rilpivirine     DB08864
# 149        Crizotinib     DB08865
# 151      Cabozantinib     DB08875
# 152         Ponatinib     DB08901
# 168        Cobicistat     DB09065
# 169        Lenvatinib     DB09078
# 174      Azelnidipine     DB09230
# 178       Osimertinib     DB09330
# 180        Venetoclax     DB11581
# 183         Tucatinib     DB11652
# 184      Latrepirdine     DB11725
# 186      Cenicriviroc     DB11758
# 189        Capmatinib     DB11791
# 191     Ruboxistaurin     DB11829
# 193       Decoglurant     DB11923
# 197       Abemaciclib     DB12001
# 205      Sotrastaurin     DB12369
# 206       Bemcentinib     DB12411
# 211        LY-2584702     DB12690
# 214       Intoplicine     DB12868
# 220         Olmutinib     DB13164
# 222       Lofepramine     DB13411
# 238      Ridinilazole     DB15308
#
#                                               SMILES_x CASRN  \
# 4    CN1C(CC2=CNC3=C2C=C(CCS(C4=CC=CC=C4)(=O)=O)C=C...     -
# 9    ClC1=C(CCN2CCN(CC2)C3=NSC4=CC=CC=C34)C=C5CC(=O...     -
# 11   COC1=C(NC2=C3C=CC=CC3=NC4=CC=CC=C24)C=CC(NS(C)...     -
# 23   C12N(C)C3=CC(OC)=C(C=C3C14CCN5CC=CC(CC)(C45)C(...     -
# 26         CN1CCN(CC1)C2=NC3=CC=CC=C3OC4=C2C=C(Cl)C=C4     -
# 36   C12N(C)C3=CC(OC)=C(C=C3C14CCN5CC=CC(CC)(C(OC(C...     -
# 37    CCN(CC)CC1=C(O)C=CC(NC2=C3C=CC(Cl)=CC3=NC=C2)=C1     -
# 38          RIFABUTIN     -  847.1   6.887  73.23  123.60  ...
# 39           Imatinib     -  493.7   7.260  43.19   67.64  ...
# 50        Clopidogrel     -  321.9   8.699  24.68   37.23  ...
# 55        Clofazimine     -  473.4   8.608  38.01   54.89  ...
# 61   Phenoxybenzamine     -  303.9   7.067  26.36   42.47  ...
# 65      Desloratadine     -  310.9   7.582  26.61   40.48  ...
# 70         Rifampicin     -  823.0   7.035  69.89  118.20  ...
# 72         Atazanavir     -  705.0   6.844  61.25  103.20  ...
# 74        Deserpidine     -  578.7   7.234  49.24   80.73  ...
# 87        RIFAPENTINE     -  877.2   6.907  75.47  127.80  ...
# 91       ARIPIPRAZOLE     -  448.4   7.867  36.00   57.09  ...
# 96          Lapatinib     -  581.1   8.805  44.66   67.23  ...
# 97          Sunitinib     -  398.5   7.117  34.22   56.18  ...
# 98          josamycin     -  828.1   6.521  71.65  128.10  ...
# 100         ALMITRINE     -  477.6   7.463  40.24   64.34  ...
# 102       Thiothixene     -  443.7   7.520  36.72   58.60  ...
# 113       Indacaterol     -  392.5   6.887  35.04   56.67  ...
# 114        Rilapladib     -  735.9   8.176  58.85   91.60  ...
# 117        Tandutinib     -  562.8   6.781  49.47   82.82  ...
# 118       Abiraterone     -  349.6   6.133  33.64   55.68  ...
# 119           OSI-930     -  443.5   9.436  33.05   48.64  ...
# 129       Enzastaurin     -  515.7   7.583  44.86   67.77  ...
# 130         Pazopanib     -  437.6   8.103  34.98   54.51  ...
# 131      Panobinostat     -  349.5   7.132  30.76   48.80  ...
# 136        Vilazodone     -  441.6   7.360  38.33   59.88  ...
# 140          CHIR-124     -  420.0   8.076  34.39   52.11  ...
# 141           AMG-208     -  383.4   8.336  31.70   46.47  ...
# 143             PQ-10     -  403.5   7.911  33.47   51.56  ...
# 148       Rilpivirine     -  366.5   7.967  31.29   45.91  ...
# 149        Crizotinib     -  450.4   8.661  34.13   52.83  ...
# 151      Cabozantinib     -  501.5   8.222  40.82   62.17  ...
# 152         Ponatinib     -  532.6   8.070  43.31   67.08  ...
# 168        cobicistat     -  776.1   7.254  65.21  106.80  ...
# 169        Lenvatinib     -  426.9   8.712  32.99   50.11  ...
# 174      Azelnidipine     -  582.7   7.568  49.28   77.62  ...
# 178       Osimertinib     -  499.7   7.138  43.43   69.85  ...
# 180        Venetoclax     -  868.5   7.825  70.76  111.80  ...
# 183         Tucatinib     -  480.6   8.010  39.82   60.54  ...
# 184      Latrepirdine     -  319.5   6.520  29.86   48.03  ...
# 186      Cenicriviroc     -  697.0   6.834  61.78  101.00  ...
# 189        Capmatinib     -  412.5   8.593  33.39   48.75  ...
# 191     Ruboxistaurin     -  468.6   7.438  40.55   62.99  ...
# 193       Decoglurant     -  447.4  10.400  31.57   45.89  ...
# 197       Abemaciclib     -  506.7   7.343  42.79   69.33  ...
# 205      Sotrastaurin     -  438.5   7.973  36.77   55.33  ...
# 206       Bemcentinib     -  506.7   7.038  45.02   71.30  ...
# 141  COC1=CC2=NC=CC(OCC3=NN=C4C=CC(=NN34)C5=CC=CC=C...       True
# 143  COC1=CC2=NC=NC(N3CCC(C3)OC4=NC5=CC=CC=C5N=C4)=...       True
# 148  CC1=CC(\C=C\C#N)=CC(C)=C1NC1=CC=NC(NC2=CC=C(C=...       True
# 149  C[C@@H](OC1=CC(=CN=C1N)C1=CN(N=C1)C1CCNCC1)C1=...       True
# 151  COC1=CC2=C(C=C1OC)C(OC1=CC=C(NC(=O)C3(CC3)C(=O...       True
# 152  CN1CCN(CC2=CC=C(NC(=O)C3=CC(C#CC4=CN=C5C=CC=NN...       True
# 168  CC(C)C1=NC(CN(C)C(=O)N[C@@H](CCN2CCOCC2)C(=O)N...      False
# 169  COC1=C(C=C2C(OC3=CC=C(NC(=O)NC4CC4)C(Cl)=C3)=C...       True
# 174  CC(C)OC(=O)C1=C(C)NC(N)=C(C1C1=CC=CC(=C1)[N+](...       True
# 178  COC1=C(NC2=NC=CC(=N2)C2=CN(C)C3=C2C=CC=C3)C=C(...       True
# 180  CC1(C)CCC(CN2CCN(CC2)C2=CC=C(C(=O)NS(=O)(=O)C3...       True
# 183  CC1=CC(NC2=NC=NC3=CC=C(NC4=NC(C)(C)CO4)C=C23)=...       True
# 184      CN1CCC2=C(C1)C1=CC(C)=CC=C1N2CCC1=CC=C(C)N=C1      False
# 186  CCCCOCCOC1=CC=C(C=C1)C2=CC3=C(C=C2)N(CC(C)C)CC...       True
# 189  CNC(=O)C1=C(F)C=C(C=C1)C2=NN3C(CC4=CC5=C(C=C4)...      False
# 191  CN(C)CC1CCN2C=C(C3=C2C=CC=C3)C4=C(C(=O)NC4=O)C...       True
# 193  NC1=CC=C(C=N1)C#CC2=C3N=C(C=C(N3N=C2)C(F)(F)F)...       True
# 197  CCN1CCN(CC2=CC=C(NC3=NC=C(F)C(=N3)C4=CC(F)=C5N...       True
# 205  CN1CCN(CC1)C2=NC(C3=C(C(=O)NC3=O)C4=CNC5=C4C=C...       True
# 206  NC1=NC(NC2=CC=C3CCC(CCC3=C2)N4CCCC4)=NN1C5=CC6...       True
# 211  CN1C=C(N=C1C2CCN(CC2)C3=C4C=NNC4=NC=N3)C5=CC=C...       True
# 214  CN(C)CCCNC1=NC=C(C)C2=C1C3=C(N2)C=CC4=CC(O)=CC...       True
# 220  CN1CCN(CC1)C2=CC=C(NC3=NC(OC4=CC=CC(NC(=O)C=C)...       True
# 222  CN(CCCN1C2=CC=CC=C2CCC3=CC=CC=C13)CC(=O)C4=CC=...      False
# 238  N1C2=CC(=CC=C2N=C1C3=CC=NC=C3)C4=CC5=C(C=C4)N=...       True
#
# [58 rows x 5674 columns]

# %%
excluded_out = excluded_drugs.apply(lambda x: predict_siRNA_complexation(x,x['name']),axis=1)
excluded_out
# Out:
#                  Name  Prediction  \
# 4          Eletriptan       False
# 9         Ziprasidone        True
# 11          Amsacrine       False
# 23        Vinorelbine       False
# 26           Loxapine       False
# 36        Vinblastine       False
# 37        Amodiaquine        True
# 38          Rifabutin       False
# 39           Imatinib        True
# 50        Clopidogrel       False
# 55        Clofazimine        True
# 61   Phenoxybenzamine       False
# 65      Desloratadine       False
# 70         Rifampicin       False
# 72         Atazanavir        True
# 74        Deserpidine       False
# 87        Rifapentine       False
# 91       Aripiprazole       False
# 96          Lapatinib        True
# 97          Sunitinib       False
# 98          Josamycin       False
# 100         Almitrine        True
# 102       Thiothixene       False
# 113       Indacaterol       False
# 114        Rilapladib        True
# 117        Tandutinib       False
# 118       Abiraterone       False
# 119           OSI-930        True
# 129       Enzastaurin       False
# 130         Pazopanib       False
# 131      Panobinostat        True
# 136        Vilazodone        True
# 140          CHIR-124       False
# 141           AMG-208       False
# 143             PQ-10       False
# 148       Rilpivirine        True
# 149        Crizotinib        True
# 151      Cabozantinib        True
# 152         Ponatinib        True
# 168        Cobicistat        True
# 169        Lenvatinib       False
# 174      Azelnidipine       False
# 178       Osimertinib        True
# 180        Venetoclax       False
# 183         Tucatinib       False
# 184      Latrepirdine       False
# 186      Cenicriviroc        True
# 189        Capmatinib       False
# 191     Ruboxistaurin       False
# 193       Decoglurant        True
# 197       Abemaciclib        True
# 205      Sotrastaurin       False
# 206       Bemcentinib        True
# 211        LY-2584702       False
# 214       Intoplicine       False
# 220         Olmutinib        True
# 222       Lofepramine        True
# 238      Ridinilazole       False
#
#                                                Comment
# 4    ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 9    ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 11   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 23   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 26   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 36   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 37   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 38   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 39   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 50   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 55   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 61   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 65   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 70   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 72   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 74   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 87   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 91   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 96   ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 97   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 98   ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 100  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 102  ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 113  ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 114           ALOGP > 8.0 - Predicted to complex siRNA
# 117  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 118  ALOGP < 8.0 & nAB <= 12 - Predicted NOT to com...
# 119  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 129  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 130  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 131  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 136  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 140  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 141  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 143  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 148  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 149  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 151  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 152  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 168  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 169  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 174  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 178  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 180  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 183  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 184  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 186  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 189  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 191  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 193  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 197  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 205  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 206  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 211  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 214  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 220  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 222  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...
# 238  ALOGP < 8.0 & nAB > 12 & NOArRing > 0 - Classi...

# %%
sum(excluded_out['Prediction'])
# Out:
# 23

# %%
sum(excluded_drugs['RG_binary'])
# Out:
# 39

# %%
excluded_drugs[excluded_drugs['ALOGP']>8][['name','RG_binary']]
# Out:
#            name  RG_binary
# 114  Rilapladib       True

# %%
excluded_drugs[excluded_drugs['nAB']<=12][['name','RG_binary']]
# Out:
#                  name  RG_binary
# 26           Loxapine      False
# 38          Rifabutin      False
# 50        Clopidogrel      False
# 61   Phenoxybenzamine      False
# 65      Desloratadine      False
# 70         Rifampicin      False
# 87        Rifapentine      False
# 91       Aripiprazole       True
# 97          Sunitinib       True
# 98          Josamycin      False
# 102       Thiothixene       True
# 113       Indacaterol      False
# 118       Abiraterone      False

# %%
# generate preductions and confusion matrix for train set
cm = confusion_matrix(excluded_drugs['RG_binary'], excluded_out['Prediction'], labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)
disp.plot()
